# %% [markdown]
# ## Filter Function is going to retieve only those items which are meeting a certain condition in an iterable

# %% [markdown]
# ### The filter function constructs an Iterator from elements of an iterable for which a condition remains True or for which a Function returns True Value

# %% [markdown]
# ###Syntax for Filter Function
# ## list(filter(func, iterable))

# %%
def even_function (value):
    if value%2==0:
        return True

# %%
iterable_list=[1,4,5,9,2,6,3,711, 24, 23, 29, 22, 32, 38,96]
print(list(filter(even_function, iterable_list)))
# Out:
# [4, 2, 6, 24, 22, 32, 38, 96]

# %%
## Solving the similar problem statement with a Lambda Function

print(list(filter (lambda x:x%2==0, iterable_list)))
# Out:
# [4, 2, 6, 24, 22, 32, 38, 96]

# %%
## I want to retrieve the values which are greater than 5
print(list(filter (lambda x:x>5, iterable_list)))
# Out:
# [9, 6, 711, 24, 23, 29, 22, 32, 38, 96]

# %%
## I want to retrieve all those values which are greater than 5 as well and are even as well
list_items=[1,6,8,2,6,1,11,66,67,15,63]
print(list (filter (lambda x : x > 5 and x%2==0,list_items)))
# Out:
# [6, 8, 6, 66]

# %%
## Iterating over the dictionary items
employees= [{'Name': 'Amit', 'Age':23, 'Qualification': 'BTech in Computer Science'},
{'Name': 'Vivek', 'Age': 25, 'Qualification': 'Bcom'},
{'Name': 'Sunil', 'Age': 29, 'Qualification': 'BTech in Electronics'},
{'Name': 'Srishti', 'Age': 33, 'Qualification': 'BTech in Petroleum'}]

# %%
def age_greater (employe):
    if employe ['Age']>25:
        return True

# %%
print(list(filter(age_greater, employees)))
# Out:
# [{'Name': 'Sunil', 'Age': 29, 'Qualification': 'BTech in Electronics'}, {'Name': 'Srishti', 'Age': 33, 'Qualification': 'BTech in Petroleum'}]
