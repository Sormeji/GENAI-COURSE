# %% [markdown]
# ## Lamda Function

# %% [markdown]
# Lamda function is a one liner functoin defined by the lamda keyword

# %% [markdown]
# ## Syntax for Lambda Function:
# ## lambda arguments: expression
# ## lambda-->keyword which simpally let the python interpreter know that the current function is our Lambda Function
# ## Arguments --> Input values for our Function
# ## Expression ---> Logic( Function Body)

# %% [markdown]
# ## lamda x:x**2

# %% [markdown]
# ## They can have any number of Arguments but only one expression or only one Logic
# ## They are used for Short Operations or as Arguments to Higher Order Functions

# %% [markdown]
# ## only in basic of  kind functions problem statemnt lamda fn can be ussed

# %% [markdown]
# ## lamda function can be treated as a function without a name and they dont even require a return statement

# %%
lambda_function= lambda x: x**2

# %%
lambda_function(5)
# Out:
# 25

# %%
sum = lambda a, b: a + b
print(sum(5, 10))
# Out:
# 15
