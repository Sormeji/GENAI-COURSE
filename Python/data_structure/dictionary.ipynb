# %% [markdown]
# ## Dictionary

# %% [markdown]
# ### Happy->Meaning
# ### Sad ->Meaning

# %% [markdown]
# Dictionary in data sturucture are going to store the values in similar way just like the general dictionary in key-value form.

# %% [markdown]
# ### syntax for dictionary is
# ### {key_1=value_1,key_2=value_2,key_3=value3}

# %% [markdown]
# ### Gathering the data as a data analyst or as a Data Engineer from websites and now i want to store the data in a format as :
# ### Columns + Rows
# ### Name Email Phone
# ### Amit amitks 123
# ### Vivek vivek..2435

# %% [markdown]
# ### {"Name": ['Amit', 'Vivek', 'Vikas']
# ### "Email":"aiyish@gmail.com","vivek@gmail.com","vikas@gmail.com", "Phone num"[134,245.3456]}

# %%
dictionary={"Name":"Amit", "Phone": "354684","email":"amitmslms@gmail.com", "Qualification":"BTech"}

# %%
dictionary
# Out:
# {'Name': 'Amit',
#  'Phone': '354684',
#  'email': 'amitmslms@gmail.com',
#  'Qualification': 'BTech'}

# %%
type(dictionary)
# Out:
# dict

# %% [markdown]
# Dictionary will be having key value combinations and
# are ordered in a way such that only by using key name
# we can access the values that are their inside the
# dictionary and in a similar way dictionary is preffered
# as immutable so that for a specific key there must be a
# specific value associated
