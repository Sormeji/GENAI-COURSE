# %% [markdown]
# # list is a type of data structure which is used to store every data types and also we can use curd funcgtions like create, read, update, delete,etc

# %%
a=list()

# %%
type(a)
# Out:
# list

# %% [markdown]
# # keywords are the reserve words that cant be used as a variable

# %%
lists=[1,2,3,4,5]

# %%
print(lists)
# Out:
# [1, 2, 3, 4, 5]

# %%
print(lists[2])
# Out:
# 3

# %%
print(lists[-1])
# Out:
# 5

# %%
lists[1:4]
# Out:
# [2, 3, 4]

# %%
print(lists[:])
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # tuples

# %% [markdown]
# ### tuples are also kind of list which we can store the data type in a ordered way but the tuples are non mutable

# %%
a=tuple()

# %%
type(a)
# Out:
# tuple

# %%
tuples=(1,2,3,4,5)

# %%
print(tuples)
# Out:
# (1, 2, 3, 4, 5)

# %%
tuples[2]
# Out:
# 3

# %%
tuples[2]=22
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 tuples[2]=22
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### this is the difference

# %% [markdown]
# ### like list, tuple can also store different type of data types

# %% [markdown]
# tuples we are going to have two methods
# 1.count
# 2.index

# %%
tuple_method=(1,2,3,4,2,1,42,32,1,2,3,4,5)

# %%
tuple_method.count(1)
# Out:
# 3

# %%
tuple_method.index(1)
# Out:
# 0

# %% [markdown]
# ### packing and unpacking of tuples

# %%
#packing of tuples
a=1,2,4,5,6,7,7,8,3,45,23,34

# %%
print(a)
# Out:
# (1, 2, 4, 5, 6, 7, 7, 8, 3, 45, 23, 34)

# %%
#unpacking of tuples
a,b,c,d,e=(1,2,3,4,5)

# %%
print(a)
# Out:
# 1
