# %% [markdown]
# ### Sets are going to be our third data structure which can store values inside it wthin the curly braces {} and are known for storing the values which are Non Duplicate and unique

# %%
a=set()

# %%
type(a)
# Out:
# set

# %% [markdown]
# ### add() is used to add values

# %%
set_values={1,2,3,4,5}

# %%
set_values.add(6)

# %%
set_values
# Out:
# {1, 2, 3, 4, 5}

# %%
for i in range(1,20):
    set_values.add(i)

# %%
set_values
# Out:
# {1, 2, 3, 4, 5}

# %%
fruits={'apple', 'banana', 'grapes', 'lichi', 'pineapple', 'guava'}

# %%
fruit_vegetables = ['apple', 'banana', 'potato', 'onion', 'capsicum']

# %%
for item in fruit_vegetables:
    fruits.add(item)

# %%
fruits
# Out:
# {'apple',
#  'banana',
#  'capsicum',
#  'grapes',
#  'guava',
#  'lichi',
#  'onion',
#  'pineapple',
#  'potato'}
